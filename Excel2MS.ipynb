# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcinSaferna/SingleMolecue/blob/main/Excel2MS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install h5py
# !pip install typing-extensions
# !pip install wheel
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.22.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (4.7.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (0.41.0)

# %%
# !pip install tensorflow==2.8
# Out:
# Collecting tensorflow==2.8
#   Downloading tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (23.5.26)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.8.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 44.1 MB/s eta 0:00:00
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 19.7 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow==2.8)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 38.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.56.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.41.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.27.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 30.1 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 29.6 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.2)
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, keras, tensorboard-data-server, keras-preprocessing, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.1
#     Uninstalling tensorboard-data-server-0.7.1:
#       Successfully uninstalled tensorboard-data-server-0.7.1
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.3
#     Uninstalling tensorboard-2.12.3:
#       Successfully uninstalled tensorboard-2.12.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# Successfully installed google-auth-oauthlib-0.4.6 keras-2.8.0 keras-preprocessing-1.1.2 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
tf.__version__
# Out:
# '2.8.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/praktyki/rawDataSingleMolecule/gotowe.zip'
zip_object = zipfile.ZipFile(file=path, mode='r')
zip_object.extractall('./')
zip_object.close()

# %%
training_generator = ImageDataGenerator(rescale=1./255,
                                        horizontal_flip=True,
                                        vertical_flip=True)

# %%
train_dataset = training_generator.flow_from_directory('/content/gotowe/train_set',
                                                       target_size = (100, 100),
                                                       batch_size = 10,
                                                       color_mode='rgb',
                                                       class_mode = 'categorical',
                                                       shuffle = True)
# Out:
# Found 11158 images belonging to 7 classes.

# %%
train_dataset.classes
# Out:
# array([0, 0, 0, ..., 6, 6, 6], dtype=int32)

# %%
train_dataset.class_indices
# Out:
# {'nematyk': 0,
#  'smektyk_C': 1,
#  'smektyk_F': 2,
#  'smektyk_GMosaic': 3,
#  'smektyk_GSchliren': 4,
#  'smektyk_H': 5,
#  'smektyk_I': 6}

# %%
test_generator = ImageDataGenerator(rescale=1./255)
val_generator = ImageDataGenerator(rescale=1./255)

# %%
validation_dataset = val_generator.flow_from_directory('/content/gotowe/val_set',
                                                        target_size=(100, 100),
                                                        batch_size=1,
                                                        class_mode='categorical',
                                                        color_mode='rgb',
                                                        shuffle=True) # set as validation data
# Out:
# Found 1395 images belonging to 7 classes.

# %%
L2 = 0.00001

# %%
test_datatset = test_generator.flow_from_directory('/content/gotowe/test_set',
                                                   target_size = (100, 100),
                                                   batch_size = 1,
                                                   color_mode='rgb',
                                                   class_mode = 'categorical',
                                                   shuffle = False)
# Out:
# Found 1396 images belonging to 7 classes.

# %%
initializer1 = tf.keras.initializers.HeNormal()
initializer2 = tf.keras.initializers.GlorotUniform()

# %%
network = Sequential()
network.add(Conv2D(filters=16, kernel_size=(3,3), activation = 'relu', input_shape = (100,100,3), kernel_initializer=initializer1))
network.add(Conv2D(filters=16, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=16, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=32, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=32, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=32, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))


network.add(Conv2D(filters=64, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
#network.add(Conv2D(filters=64, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=128, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=128, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=256, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
#network.add(Conv2D(filters=256, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

#network.add(Conv2D(filters=512, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
#network.add(Conv2D(filters=512, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
#network.add(BatchNormalization())
#network.add(MaxPool2D(pool_size=(2,2)))

network.add(Flatten())

network.add(Dropout(0.11))
network.add(Dense(units = 512, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 256, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 128, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
#network.add(Dense(units = 64, activation = 'relu', kernel_initializer=initializer1))
#network.add(BatchNormalization())
network.add(Dense(units = 32, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 16, activation = 'relu', kernel_initializer=initializer1, kernel_regularizer=tf.keras.regularizers.L1L2()))
network.add(BatchNormalization())
network.add(Dense(units = 7, activation = 'softmax', kernel_initializer=initializer2))
network.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 98, 98, 16)        448
#
#  conv2d_21 (Conv2D)          (None, 98, 98, 16)        2320
#
#  conv2d_22 (Conv2D)          (None, 98, 98, 16)        2320
#
#  batch_normalization_31 (Bat  (None, 98, 98, 16)       64
#  chNormalization)
#
#  max_pooling2d_16 (MaxPoolin  (None, 49, 49, 16)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 49, 49, 32)        4640
#
#  conv2d_24 (Conv2D)          (None, 49, 49, 32)        9248
#
#  conv2d_25 (Conv2D)          (None, 49, 49, 32)        9248
#
#  batch_normalization_32 (Bat  (None, 49, 49, 32)       128
#  chNormalization)
#
#  max_pooling2d_17 (MaxPoolin  (None, 24, 24, 32)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 24, 24, 64)        18496
#
#  batch_normalization_33 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  max_pooling2d_18 (MaxPoolin  (None, 12, 12, 64)       0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 12, 12, 128)       73856
#
#  conv2d_28 (Conv2D)          (None, 12, 12, 128)       147584
#
#  batch_normalization_34 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  max_pooling2d_19 (MaxPoolin  (None, 6, 6, 128)        0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 6, 6, 256)         33024
#
#  batch_normalization_35 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  max_pooling2d_20 (MaxPoolin  (None, 3, 3, 256)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 2304)              0
#
#  dropout_3 (Dropout)         (None, 2304)              0
#
#  dense_18 (Dense)            (None, 512)               1180160
#
#  batch_normalization_36 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_19 (Dense)            (None, 256)               131328
#
#  batch_normalization_37 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_20 (Dense)            (None, 128)               32896
#
#  batch_normalization_38 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_21 (Dense)            (None, 32)                4128
#
#  batch_normalization_39 (Bat  (None, 32)               128
#  chNormalization)
#
#  dense_22 (Dense)            (None, 16)                528
#
#  batch_normalization_40 (Bat  (None, 16)               64
#  chNormalization)
#
#  dense_23 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 1,656,103
# Trainable params: 1,653,223
# Non-trainable params: 2,880
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
#opt = Adam(lr=0.005)
opt = Adam()
network.compile(optimizer='Adam', loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
es = EarlyStopping(monitor = 'val_accuracy', min_delta = 0.001, patience = 20, verbose =1)
model_cp = ModelCheckpoint(filepath = 'best_model1.h5', monitor = 'val_accuracy', save_best_only = True, verbose = 1)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1, factor=0.5, min_lr=0.00001)

# %%
history = network.fit_generator(train_dataset,
                                steps_per_epoch = 50,
                                validation_data = validation_dataset,
                                validation_steps = 50,
                                epochs=100,
                                callbacks=[es, model_cp, learning_rate_reduction])
# Out:
# Epoch 1/100
# <ipython-input-45-d45876fe1552>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = network.fit_generator(train_dataset,
# 50/50 [==============================] - ETA: 0s - loss: 1.9568 - accuracy: 0.2880
# Epoch 1: val_accuracy improved from -inf to 0.30000, saving model to best_model1.h5
# 50/50 [==============================] - 35s 665ms/step - loss: 1.9568 - accuracy: 0.2880 - val_loss: 1.9100 - val_accuracy: 0.3000 - lr: 0.0010
# Epoch 2/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6220 - accuracy: 0.4200
# Epoch 2: val_accuracy did not improve from 0.30000
# 50/50 [==============================] - 31s 616ms/step - loss: 1.6220 - accuracy: 0.4200 - val_loss: 2.8977 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 3/100
# 50/50 [==============================] - ETA: 0s - loss: 1.5357 - accuracy: 0.4220
# Epoch 3: val_accuracy did not improve from 0.30000
# 50/50 [==============================] - 30s 608ms/step - loss: 1.5357 - accuracy: 0.4220 - val_loss: 1.9951 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 4/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4157 - accuracy: 0.4940
# Epoch 4: val_accuracy did not improve from 0.30000
# 50/50 [==============================] - 30s 595ms/step - loss: 1.4157 - accuracy: 0.4940 - val_loss: 2.3428 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 5/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4334 - accuracy: 0.4700
# Epoch 5: val_accuracy did not improve from 0.30000
# 50/50 [==============================] - 29s 588ms/step - loss: 1.4334 - accuracy: 0.4700 - val_loss: 2.6530 - val_accuracy: 0.2200 - lr: 0.0010
# Epoch 6/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3385 - accuracy: 0.5220
# Epoch 6: val_accuracy did not improve from 0.30000
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 50/50 [==============================] - 32s 642ms/step - loss: 1.3385 - accuracy: 0.5220 - val_loss: 2.8876 - val_accuracy: 0.1600 - lr: 0.0010
# Epoch 7/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3143 - accuracy: 0.5321
# Epoch 7: val_accuracy improved from 0.30000 to 0.34000, saving model to best_model1.h5
# 50/50 [==============================] - 29s 568ms/step - loss: 1.3143 - accuracy: 0.5321 - val_loss: 2.9049 - val_accuracy: 0.3400 - lr: 5.0000e-04
# Epoch 8/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3338 - accuracy: 0.5382
# Epoch 8: val_accuracy improved from 0.34000 to 0.36000, saving model to best_model1.h5
# 50/50 [==============================] - 31s 629ms/step - loss: 1.3338 - accuracy: 0.5382 - val_loss: 2.1635 - val_accuracy: 0.3600 - lr: 5.0000e-04
# Epoch 9/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1404 - accuracy: 0.6220
# Epoch 9: val_accuracy did not improve from 0.36000
# 50/50 [==============================] - 41s 812ms/step - loss: 1.1404 - accuracy: 0.6220 - val_loss: 2.1461 - val_accuracy: 0.2800 - lr: 5.0000e-04
# Epoch 10/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1869 - accuracy: 0.5680
# Epoch 10: val_accuracy improved from 0.36000 to 0.48000, saving model to best_model1.h5
# 50/50 [==============================] - 32s 652ms/step - loss: 1.1869 - accuracy: 0.5680 - val_loss: 1.4617 - val_accuracy: 0.4800 - lr: 5.0000e-04
# Epoch 11/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0746 - accuracy: 0.6080
# Epoch 11: val_accuracy improved from 0.48000 to 0.70000, saving model to best_model1.h5
# 50/50 [==============================] - 32s 637ms/step - loss: 1.0746 - accuracy: 0.6080 - val_loss: 1.1588 - val_accuracy: 0.7000 - lr: 5.0000e-04
# Epoch 12/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1727 - accuracy: 0.6000
# Epoch 12: val_accuracy improved from 0.70000 to 0.74000, saving model to best_model1.h5
# 50/50 [==============================] - 31s 631ms/step - loss: 1.1727 - accuracy: 0.6000 - val_loss: 0.7718 - val_accuracy: 0.7400 - lr: 5.0000e-04
# Epoch 13/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0276 - accuracy: 0.6500
# Epoch 13: val_accuracy did not improve from 0.74000
# 50/50 [==============================] -
100
# 50/50 [==============================] - ETA: 0s - loss: 0.9214 - accuracy: 0.6900
# Epoch 28: val_accuracy did not improve from 0.80000
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 50/50 [==============================] - 31s 632ms/step - loss: 0.9214 - accuracy: 0.6900 - val_loss: 0.7320 - val_accuracy: 0.7200 - lr: 2.5000e-04
# Epoch 29/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9488 - accuracy: 0.6940
# Epoch 29: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 30s 595ms/step - loss: 0.9488 - accuracy: 0.6940 - val_loss: 0.7955 - val_accuracy: 0.7000 - lr: 1.2500e-04
# Epoch 30/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9791 - accuracy: 0.6620
# Epoch 30: val_accuracy improved from 0.80000 to 0.82000, saving model to best_model1.h5
# 50/50 [==============================] - 32s 635ms/step - loss: 0.9791 - accuracy: 0.6620 - val_loss: 0.5663 - val_accuracy: 0.8200 - lr: 1.2500e-04
# Epoch 31/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8664 - accuracy: 0.7240
# Epoch 31: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 31s 616ms/step - loss: 0.8664 - accuracy: 0.7240 - val_loss: 0.7541 - val_accuracy: 0.7400 - lr: 1.2500e-04
# Epoch 32/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8972 - accuracy: 0.7020
# Epoch 32: val_accuracy improved from 0.82000 to 0.88000, saving model to best_model1.h5
# 50/50 [==============================] - 31s 632ms/step - loss: 0.8972 - accuracy: 0.7020 - val_loss: 0.4201 - val_accuracy: 0.8800 - lr: 1.2500e-04
# Epoch 33/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9553 - accuracy: 0.6640
# Epoch 33: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 28s 561ms/step - loss: 0.9553 - accuracy: 0.6640 - val_loss: 0.6382 - val_accuracy: 0.7800 - lr: 1.2500e-04
# Epoch 34/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8986 - accuracy: 0.6560
# Epoch 34: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 32s 629ms/step - loss: 0.8986 - accuracy: 0.6560 - val_loss: 0.6542 - val_accuracy: 0.8200 - lr: 1.2500e-04
# Epoch 35/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8692 - accuracy: 0.6980
# Epoch 35: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 31s 633ms/step - loss: 0.8692 - accuracy: 0.6980 - val_loss: 0.5956 - val_accuracy: 0.8600 - lr: 1.2500e-04
# Epoch 36/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8753 - accuracy: 0.6900
# Epoch 36: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 28s 563ms/step - loss: 0.8753 - accuracy: 0.6900 - val_loss: 0.7097 - val_accuracy: 0.7600 - lr: 1.2500e-04
# Epoch 37/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9489 - accuracy: 0.6740
# Epoch 37: val_accuracy did not improve from 0.88000
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 50/50 [==============================] - 31s 632ms/step - loss: 0.9489 - accuracy: 0.6740 - val_loss: 0.8550 - val_accuracy: 0.7400 - lr: 1.2500e-04
# Epoch 38/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8413 - accuracy: 0.7200
# Epoch 38: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 30s 601ms/step - loss: 0.8413 - accuracy: 0.7200 - val_loss: 0.5897 - val_accuracy: 0.8200 - lr: 6.2500e-05
# Epoch 39/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8526 - accuracy: 0.7080
# Epoch 39: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 32s 634ms/step - loss: 0.8526 - accuracy: 0.7080 - val_loss: 0.6976 - val_accuracy: 0.7600 - lr: 6.2500e-05
# Epoch 40/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8112 - accuracy: 0.7380
# Epoch 40: val_accuracy did not improve from 0.88000
# 50/50 [==============================] -
val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 30s 602ms/step - loss: 0.8095 - accuracy: 0.7260 - val_loss: 0.6410 - val_accuracy: 0.8000 - lr: 1.0000e-05
# Epoch 72/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7697 - accuracy: 0.7180
# Epoch 72: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 29s 576ms/step - loss: 0.7697 - accuracy: 0.7180 - val_loss: 0.5252 - val_accuracy: 0.8000 - lr: 1.0000e-05
# Epoch 73/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7581 - accuracy: 0.7620
# Epoch 73: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 32s 634ms/step - loss: 0.7581 - accuracy: 0.7620 - val_loss: 0.3990 - val_accuracy: 0.8400 - lr: 1.0000e-05
# Epoch 74/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7211 - accuracy: 0.7700
# Epoch 74: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 30s 602ms/step - loss: 0.7211 - accuracy: 0.7700 - val_loss: 0.6398 - val_accuracy: 0.7800 - lr: 1.0000e-05
# Epoch 75/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7935 - accuracy: 0.7380
# Epoch 75: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 30s 596ms/step - loss: 0.7935 - accuracy: 0.7380 - val_loss: 0.6074 - val_accuracy: 0.7600 - lr: 1.0000e-05
# Epoch 75: early stopping

# %%
predictions=network.predict(test_datatset)
predictions = np.argmax(predictions, axis=1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_datatset.classes, predictions)
# Out:
# 0.8187679083094556

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_datatset.classes, predictions)
sns.heatmap(cm, annot=True);

# %%
from sklearn.metrics import classification_report
print(classification_report(test_datatset.classes, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90       198
#            1       0.98      1.00      0.99       200
#            2       0.71      0.72      0.71       200
#            3       0.68      0.55      0.61       199
#            4       0.84      0.88      0.86       200
#            5       0.83      0.70      0.76       199
#            6       0.82      0.91      0.86       200
#
#     accuracy                           0.82      1396
#    macro avg       0.81      0.82      0.81      1396
# weighted avg       0.81      0.82      0.81      1396

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/best_model1.h5')

# %%
model.evaluate(test_datatset)
# Out:
# 1396/1396 [==============================] - 30s 21ms/step - loss: 0.5528 - accuracy: 0.8245
# [0.5527821779251099, 0.8244985938072205]

# %%
pred = model.predict(test_datatset)
pred = np.argmax(pred, axis=1)
cm = confusion_matrix(test_datatset.classes, pred)
sns.heatmap(cm, annot=True);

# %%
print(classification_report(test_datatset.classes, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90       198
#            1       0.97      1.00      0.99       200
#            2       0.73      0.76      0.74       200
#            3       0.72      0.53      0.61       199
#            4       0.85      0.88      0.86       200
#            5       0.81      0.72      0.76       199
#            6       0.83      0.91      0.87       200
#
#     accuracy                           0.82      1396
#    macro avg       0.82      0.82      0.82      1396
# weighted avg       0.82      0.82      0.82      1396

# %%
network.save('network.h5')

# %%
net = load_model('/content/network.h5')

# %%
net.evaluate(test_datatset)
# Out:
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.5440 - accuracy: 0.8188
# [0.5440220236778259, 0.8187679052352905]

# %%
pre = net.predict(test_datatset)
pre = np.argmax(pre, axis=1)
cm = confusion_matrix(test_datatset.classes, pre)
sns.heatmap(cm, annot=True);

# %%
print(classification_report(test_datatset.classes, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90       198
#            1       0.97      1.00      0.99       200
#            2       0.73      0.76      0.74       200
#            3       0.72      0.53      0.61       199
#            4       0.85      0.88      0.86       200
#            5       0.81      0.72      0.76       199
#            6       0.83      0.91      0.87       200
#
#     accuracy                           0.82      1396
#    macro avg       0.82      0.82      0.82      1396
# weighted avg       0.82      0.82      0.82      1396
